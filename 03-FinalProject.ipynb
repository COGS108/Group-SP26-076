# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report section Title & Abstract trhough Data Wrangling:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#
# For the report section Data Visualizations through Documentation and Written Communication:
# - Each Developing  => -1 pts
# - Each Unsatisfactory/Missing => -2 pts
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# Until the score is 0
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Ethics                                                                             | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                  | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                 | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                                                                                                     | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Data visualizations                                                                | No plots. Or most plots don't capture useful information, or their display of information is difficult to understand. Legends, labels, axes, titles, captions, etc of most plots may be poor or missing. Most figures are not referenced in the main text.                                          | Fewer than 3 relevant plots (irrelevant to the question plots do not count).  Or a few of the plots don't make sense or capture useful information. Legends, labels, axes, titles, captions, etc are illegible or inadequately describe the content in a few figures. Or a few figures are not referenced or explained inside the main text. | Plots almost all make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | No analyses beyond EDA style explorations of the dataset. Or analyses presented do not help address the question/hypothesis. Or most of the analyses presented are not technically approriate (eg. using parametric methods for non-parametric data).                                              | Only one analysis beyond EDA. Or a few analyses presented do not address the question/hypothesis. Or a few of the analyses presented are not technically approriate                                                                                                                                                                  |  At least two analyses beyond EDA. That is, the project uses two different techniques (e.g., inference vs machine learning; or t-test vs regression; or entire dataset vs stratified) or two different proxies for the same concept are investigated.  Each analysis addressed the question/hypothesis and is technically approriate. | Many different analyses are used. Each analysis addressed an aspect of the question/hypothesis and is technically approriate. Perhaps they use multiple datasets, or do something else to go the extra mile and address the reliability of the results                                            |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # Predicting NBA MVP Vote Share: The Importance of Traditional and Advanced Stats and How It Shifted Across Eras (1996-2022)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# The NBA Most Valuable Player award is determined by subjective media voting, making it one of the most debated individual honors in professional sports. This project investigates which statistical factors predict NBA MVP vote share from the 1996–97 to 2021–22 seasons and how their predictive importance shifted after the mainstream adoption of basketball analytics, using the 2003–04 publication of Dean Oliver's Basketball on Paper as our formal pivot point. Using a merged dataset of traditional box score and advanced efficiency metrics spanning 26 seasons, we applied five analyses of full-period and era-stratified Multiple Linear Regression, era-stratified Ridge Regression, and full-period and era-stratified Random Forest with permutation importance to quantify each statistic's contribution to MVP vote share and identify whether that contribution changed after 2004.
#
# Exploratory data analysis revealed that advanced efficiency metrics such as WS/48 and eFG% showed stronger correlations with vote share in the modern era compared to the pre-analytics era. Further analysis show that advanced efficiency metrics were the strongest predictors of MVP vote share across the entire period and gained further predictive power in the modern era. Composite metrics including VORP, WS/48, BPM, and net rating consistently ranked highest across both linear and machine learning models, while traditional counting statistics were weaker predictors overall. The most notable era shift was VORP nearly doubling in permutation importance and rising from third to first after 2004, suggesting media voters increasingly rewarded players who demonstrated marginal value over replacement level. Points per game retained stable predictive power across both eras in the Random Forest permutation importance rankings, though both the MLR and Ridge Regression showed a significant drop in the points coefficient from the pre-analytics to the modern era. This suggests that while scoring output remained a relevant statistical signal in the broader player population, it became a less reliable differentiator among the subset of players who actually received MVP votes.

# %% [markdown]
# ## Authors
#
# - Ari Swerdlow: Writing - original draft, Writing - review & editing, visualization
# - Conner Satawidinata: Conceptualization, Background research, Writing - review & editing, Data curation, visualization, Analysis
# - George Minasyan: Project administration, Writing - review & editing, visualization, Analysis
# - Ghaida Alruwais: Writing - original draft, Data curation, Merging datasets, visualization, Analysis
# - Guthry Hahm: Writing - original draft, Writing - review & editing, visualization

# %% [markdown]
# ## Research Question

# %% [markdown]
# Which factors predict NBA MVP voting share from 1996 to 2022, and how has their importance shifted across the eras?
#
# - Which player statistics (points, assists, rebounds) and advanced efficiency metrics (BPM, Win Shares/48) are the strongest predictors of MVP vote share across the entire 1996-2022 period?
# - How does the predictive importance of traditional (points, assists, rebounds) versus advanced metrics (BPM, Win Shares/48) differentiate between the pre-analytics era (1996-2004) and modern era (2004-2022)?
#
# Our dataset combines per-game player statistics from Kaggle using manually added MVP vote sharing data and advanced stats from Basketball Reference. This means this is mainly a prediction + statistical inference task, and requires us to use regression-based models in order to count each statistic’s contribution to the vote share, and then compare the importance of features across both eras to identify whether the “MVP profile” changed alongside advanced analytics becoming mainstream.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The National Basketball Association (NBA) is the predominant professional basketball league in the United States. When people talk about the NBA, a common point of discussion is who the face of the league is. A tangible way to assign this title is by looking at which player is awarded the league MVP for each NBA season. The MVP award for the NBA was introduced in 1956, ten years after the formation of the league, with the first recipient being Bob Pettit. <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) As of the 1980-1981 NBA season, the decision of which player receives the MVP award has been through voting by members of the media. <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) This subjective evaluation means that there is not a concrete formula that determines the MVP award recipient.
#
# As a result of the uncertainty in MVP voting, researchers and analysts have tried to identify which statistical factors predict MVP outcomes. Coleman and his colleagues conducted early research on the MVP races determined by media voting, specifically the seasons from 1995-2005, to form models of media voting behavior. They used a mixture of player characteristics (e.g. race and basketball position), traditional box score statistics (e.g. points, total rebounds, and assists), and team metrics (e.g. team wins and playoff qualification) to build both a Tobit and a Probit Regression model of MVP voting <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). Alongside addressing the original question on player race impacting MVP voting behavior, the models capture the significance of the traditional box score statistics. Both models indicated that a player’s points per game (PPG) was the most significant player statistic predictor of a player appearing on the MVP ballot (Probit) and the MVP voting points the player would receive (Tobit). However, the data used to build the models did not include any advanced metrics (e.g. BPM and win shares) which highlights potential confounding variables that their models did not capture.
#
# More recent research by Li and Jia applies machine learning to identify the statistical features that best predict MVP outcomes. They utilized a dataset with both traditional and advanced metrics for NBA players from 1974 to 2024 to build the five machine learning models of Random Forest, LightGBM, XGBoost, CatBoost, and NGBoost. By considering a mixture of minimizing MSE and time consumption while maximizing the R-squared coefficient, CatBoost was found to be the optimal model <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4). SHAP value analysis was used after further training of the CatBoost model to find that the most important predictors of the CatBoost’s player value scores are value over replacement player (VORP), points per game, and player efficiency rating (PER). These findings emphasize the importance of including advanced metrics in addition to traditional box score statistics in predicting MVP share. Yet, the treating of the data as a single time period leaves room for analysis across different eras and years.
#
# Godbole and his colleagues explored MVP prediction further by training an ensemble of machine learning models across the three distinct NBA eras of the Ancient Era (1990-91 to 1999-00), the Medieval Era (2000-01 to 2011-12), and the Modern Era (2012-13 to 2021-22). They applied the five machine learning models of Support Vector Regression (SVR), ElasticNet, Adaptive Boosting, Random Forest, and Gradient Boosting as well as a backpropagation neural network that they named MVPNet. MVPNet outperformed all other models, achieving an R-squared coefficient of 0.86 and correctly predicting 10 out of 10 Modern Era MVPs <a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5). SHAP analysis revealed that team statistics such as win percentage and seeding were the most important predictors in earlier eras, while advanced metrics grew more influential in the Modern Era. Although the study addresses how the predictive importance of statistics has shifted over time within each era, the primary focus of the study was on comparing how current players would perform in the MVP race across different eras.
#
# While these studies deepen the understanding of MVP prediction, their scopes do not focus on the continuity or change of MVP voting over time. Since the complete tracking of advanced metrics in the 1996-1997 season, the relative importance of these statistics compared to traditional box score statistics has not been clearly established <a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6). Numerous sports analysts have debated which performance statistics best capture player value. A particularly influential work is Dean Oliver’s 2004 publication Basketball On Paper: Rules and Tools for Performance Analysis, in which he introduced the “Four Factors of Winning” as effective field goal percentage, offensive rebound rate, turnover percentage, and free throw rate <a name="cite_ref-7"></a>[<sup>7</sup>](#cite_note-7). This suggests a transition toward efficiency rather than traditional counting stats, highlighting a potential turning point in how player performance is assessed for MVP voting. By using 2004 as a formal pivot point, we can test whether Oliver’s 'Four Factors' acted as a catalyst for media voters. While the 'Medieval' and 'Modern' eras are often grouped, our project specifically seeks to identify if 2004 was the precise moment the 'Points-Per-Game' dominance began to decay in favor of the efficiency-weighted profile Oliver championed. We are trying to capture how the predictive strength in advanced metrics compared to traditional box score statistics in gaining MVP vote share has changed over the time period spanning the 1996-1997 NBA season to the 2021-2022 NBA season.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) "NBA MVPs: Complete List of Award Winners by Year." *Fox Sports*, 2 June 2025, https://www.foxsports.com/stories/nba/nba-mvps-complete-list-of-award-winners-by-year.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) "NBA Awards Voting 2025-26." *Basketball Reference*, https://www.basketball-reference.com/awards/awards_2026.html.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Coleman, B. Jay, et al. "An Examination of NBA MVP Voting Behavior: Does Race Matter?" *Journal of Sports Economics*, vol. 9, no. 6, 2008, pp. 606–627, https://digitalcommons.unf.edu/cgi/viewcontent.cgi?article=1003&context=bmgt_facpub.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Li, Zeyang, and Lei Jia. "NBA Most Valuable Player Projection Model: Based on Traditional and Advanced Metrics." *2024 International Conference on Sports Technology and Performance Analysis* (*ICSTPA 2024*), ACM, 2024, https://dl.acm.org/doi/full/10.1145/3723936.3723963.
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Godbole, Ishan, et al. "NBA MVP Prediction and Historical Analysis Using Cross-Era Comparison Approaches." *2024 15th International Conference on Computing Communication and Networking Technologies (ICCCNT)*, IEEE, 2024, https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=10725534.
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6) "NBA.com/Stats Frequently Asked Questions." *NBA.com*, https://www.nba.com/stats/help/faq.
# 7. <a name="cite_note-7"></a> [^](#cite_ref-7) Oliver, Dean. *Basketball on Paper: Rules and Tools for Performance Analysis*. Potomac Books, 2004.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# - During 1996-2022, win shares per 48 minutes will be the strongest MVP vote share predictor, followed by points per game.
#
# We expect win shares per 48 minutes to be the strongest MVP voter share predictor because it estimates the number of wins a player contributes to their team per 48 minutes, indicating whether a player’s performance is actually valuable to winning as opposed to just being high counting statistics with no real impact. We also expect points per game to be the next strongest predictor because high scoring output is the most visible aspect of a player’s game which would create a positive perception of the player by media voters.
#
# - We predict advanced efficiency metrics (BPM, PER, TS%, etc) are stronger predictors of MVP vote share than traditional box score statistics (points, rebounds, assists, etc) in the modern era (2004-2022) than the pre-analytics era (1996-2004).
#
# Although advanced metrics were introduced in 1996, we believe media voters would not readily adopt these new statistics in their MVP voting rationale. The introduction of Dean Oliver’s “Four Factors to Winning” likely changed the way advanced metrics were perceived, leading to greater credibility of advanced metrics for media voters. As a result, we predict that voters began to value the efficiency captured through advanced metrics more than the traditional counting statistics in the post-2004 era. This shift in voter focus was potentially reinforced by the 2004 elimination of hand-checking, which fundamentally changed scoring dynamics and made perimeter efficiency a more visible driver of team success.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: NBA Players Biometric, Biographic and Basic Box Score Data (1996-2022)
#   - Link to the dataset: https://www.kaggle.com/datasets/justinas/nba-players-data
#   - Number of observations: 12,844
#   - Number of variables: 22
#   - Description of the variables most relevant to this project:
#      - player_name - The full name of the player which will be used alongside the specific season and the team the player was on for that season as the key for merging datasets.
#      - team_abbreviation - The team the player finished a specific season on which can be used alongside the player name as the key for merging datasets.
#      - gp (Games Played) - The number of games the player played during that season.
#      - pts, reb, ast - Per-game averages for points, rebounds, and assists which are core traditional box score statistics.
#      - net_rating - An estimate of a team's point differential per 100 possessions while the player is on the court.
#      - usg_pct (Usage Percentage) - An estimate of the proportion of team plays that a player was involved in while on the floor.
#      - ts_pct (True Shooting Percentage) - A composite shooting efficiency metric that accounts for 2-pointers, 3-pointers, and free throws. The values range from 0% to 100% with a higher percentage indicating more greater efficiency scoring.
#      - oreb_pct (Offensive Rebound Percentage)  - An estimate of the proportion of offensive rebounds that a player actually grabbed from the offensive rebound opportunities. The values range from 0% to 100% with a higher percentage indicating greater impact in offensive rebounding.
#      - dreb_pct (Defensive Rebound Percentage) - An estimate of the proportion of defensive rebounds that a player actually grabbed from the defensive rebound opportunities. The values range from 0% to 100% with a higher percentage indicating greater impact in defensive rebounding.
#      - season - The NBA season (e.g. "1996-97") that the per game stats and advanced metrics are drawn from.
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#      - The dataset does not have an MVP vote share column which requires this target variable to be merged in from a separate dataset.
#      - The dataset does not have any variables to track the qualitative aspects of each player’s seasons which restricts the ability to capture the impact of media narratives and stores on MVP vote share.
#      - The dataset is missing some key advanced metrics, such as Value Over Replacement Player (VORP) and Box Plus Minus (BPM) that we want to analyze the predictive strength for MVP vote share of.
#      - The dataset is missing a few key traditional box score statistics, such as turnovers per game, blocks per game, and steals per game which requires merging these stats in from a separate dataset.
#      - The dataset does not contain the position (e.g. PG, SG, SF, PF, C) that each player plays which restricts the ability to control potential voting bias for each basketball position.
#      - The dataset contains stats for all NBA players, including players who only played a single game for a particular season, which may create noise for advanced metrics like net rating which will rely on scaling upward the small game sample size of said players.
#
# - Dataset #2
#   - Dataset Name: NBA MVP Voting Data (1996-2022)
#   - Link to the dataset: https://www.basketball-reference.com/awards/awards_1997.html (replace [1997] with any year from 1997-2022 to get all years)
#   - Number of observations: 386
#   - Number of variables: 21
#   - Description of the variables most relevant to this project:
#     - player - Full name of the player receiving MVP votes which is used as the primary key for merging with the other datasets alongside team and season.
#     - tm - Three letter team abbreviation for the team that the player ended on during that season and can be used alongside player and season as part of the merge key.
#     - share - The proportion of total possible MVP voting points a player received (ranging from 0 to 1). This is the target variable for all regression models in the project.
#     - season - The NBA season label (e.g., "1996-97") that the MVP voting is for which is used for merging and for splitting observations into pre-analytics (1996–2004) and modern (2004–2022) eras.
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#     - The dataset only includes players who received an MVP vote for a specific season which requires additional attention to fill out the vote shares of non-MVP vote-getters to be 0 when merging datasets.
#     - The dataset does not have any variables that indicate the team success of each player (e.g. team wins/team net rating) which restricts the ability to track team statistics as confounding variables of MVP vote share.
#     - Similar to the Kaggle dataset, this dataset does not have any statistics that track the narrative or stories around a player’s season which also restricts the ability to track media narrative as a confounding variable of MVP vote share.
#     - Similar to the Kaggle dataset, this dataset is missing some key advanced metrics, such as Value Over Replacement Player (VORP) and Box Plus Minus (BPM) that we want to analyze the predictive strength for MVP vote share of.
#
# - Dataset #3
#   - Dataset Name: NBA Traditional Box Score Per Game Stats (1996-2022)
#   - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_1997_per_game.html (replace [1997] with any year from 1997-2022 to get all years)
#   - Number of observations: 15,398
#   - Number of variables: 32
#   - Description of the variables most relevant to this project:
#     - Rk - The embedded index of each player in the table to help differentiate between players with the same name.
#     - Player - Full name of the player that the season statistics are linked to which is used as the primary key for merging with the other datasets alongside team and season.
#     - Team - The three letter team abbreviation for the team that the player was on when the stats were recorded. Players who were traded during the season have placeholders like “2TM” and “3TM” for overall season stats and individual rows for stats recorded on each individual team.
#     - G - The number of games that player played in for that particular season.
#     - Pos - The player's listed position (e.g., PG, SG, SF, PF, C) which can allow positional bias in MVP voting to be controlled for in regression models.
#     - STL, BLK - Per-game averages for steals, and blocks which are core traditional box score defensive statistics.
#     - TOV - Turnovers per game which is a traditional metric capturing a player’s ball security.
#     - eFG% (Effective Field Goal Percentage) - An efficiency metric, calculated as (FG + 0.5 * 3P) / (FGA),  that adjusts for the greater number of points linked to 3-pointers as opposed to the 2 points from regular field goals and is one of Dean Oliver’s Four Factors of Winning Basketball.
#     - season - The NBA season label (e.g., "1996-97") that the per game traditional box score statistics is for which is used for merging and for splitting observations into pre-analytics (1996–2004) and modern (2004–2022) eras.
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#     - Players who changed teams during a particular season (i.e. due to mid-season trades) have multiple entries for that season which requires keeping only the row with the player’s aggregate season per game stats while replacing the team entry with the team the player ended on to ensure proper merging.
#     - As a supplemental dataset focused solely on traditional per-game statistics, advanced metrics such as VORP, Win Shares, and BPM are still absent and must be merged in from a fourth dataset.
#
# - Dataset #4
#   - Dataset Name: NBA Advanced Player Stats (1996-2022)
#   - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_1997_advanced.html (replace [1997] with any year from 1997-2022 to get all years)
#   - Number of observations: 15,398
#   - Number of variables: 30
#   - Description of the variables most relevant to this project:
#     - Rk - The embedded index of each player in the table to help differentiate between players with the same name.
#     - Player - Full name of the player that the season statistics are linked to which is used as the primary key for merging with the other datasets alongside team and season.
#     - Team - The three letter team abbreviation for the team that the player was on when the stats were recorded. Players who were traded during the season have placeholders like “2TM” and “3TM” for overall season stats and individual rows for stats recorded on each individual team.
#     - G - The number of games that player played in for that particular season.
#     - PER (Player Efficiency Rating) - A per-minute rating of a player’s performance that sums up all a player's positive accomplishments while subtracting the negative accomplishments. The average PER is 15.
#     - WS/48 (Win Shares Per 48 Minutes) - An estimate of the number of wins contributed by the player per 48 minutes with the league average being approximately 0.100.
#     - TOV% - An estimate of the number of turnovers a player commits per 100 possessions and is one of Dean Oliver’s Four Factors of Winning Basketball.
#     - FTr (Free Throw Rate) - The number of free throws a player attempts per field goal attempt and is one of Dean Oliver’s Four Factors of Winning Basketball.
#     - VORP (Value Over Replacement Player) - An estimate of the number of points per 100 possessions that a player contributes to their team over a replacement player who has a -2.0 BPM.
#     - BPM (Box Plus Minus) - An estimate of a player’s contribution of points per 100 possessions over a league-average player. The average BPM is 0.0.
#     - season — The NBA season label (e.g., "1996-97") that the advanced metric statistics are collected for which is used for merging and for splitting observations into pre-analytics (1996–2004) and modern (2004–2022) eras.
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#     - Advanced metrics like VORP and BPM are very volatile if a player's game sample size is low which may create artifically high or low values for players with little playing time.
#     - Similar to the Traditional Box Score Per Game Stats dataset, this dataset also contains multiple entries for players who switched teams during a particular season, requiring the same deduplication approach of keeping only the aggregate row and replacing the team with the team they finished on.
#     - This dataset still contains no team success variables, meaning team metrics like win totals and team standing must be scraped separately.

# %% [markdown]
# ### Dataset: Kaggle NBA Players Biometric, Biographic, and Basic Box Score Data (1996–2022)
#
# To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`.

# %% [markdown]
# ### Basketball Reference NBA MVP Voting Data (1996–2022)
#
# To see the code responsible for obtaining and wrangling the data see `01-DataCheckpoint.ipynb`.

# %% [markdown]
# ### Dataset: Basketball Reference Traditional Box Score Per Game Statistics (1996-2022)
#
# To see the code responsible for obtaining and wrangling the data see `01-DataCheckpoint.ipynb`.

# %% [markdown]
# ### Dataset: Basketball Reference Advanced Player Statistics (1996-2022)
#
# To see the code responsible for obtaining and wrangling the data see `01-DataCheckpoint.ipynb`.

# %% [markdown]
# ### Merging Datasets
#
# To see the code responsible for merging the datasets together see `01-DataCheckpoint.ipynb`. From here we will simply load the final clean and wrangled merged dataset.

# %%
# import necessary general dependencies
# %load_ext autoreload
# %autoreload 2
import sys
import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# Load preprocessed data
processed_datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1VuhAbDh00i2_v1fMyvocOLzmzc01svrQ', 'filename': 'merged_clean.csv'}
]

get_data.get_raw(processed_datafiles,destination_directory='data/02-processed/')

df_merged = pd.read_csv('data/02-processed/merged_clean.csv')
# Out:
# ...
# Overall Download Progress: 100%|██████████| 1/1 [00:01<00:00,  1.78s/it]
# Successfully downloaded: merged_clean.csv

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Our exploratory data analysis explores multiple parts of the dataset by analyzing all players in the cleaned dataset, the subgroup of only players who got an MVP vote during a particular season, and stratas of player's seasons in the Pre-Analytics (1996-2004) and the Modern era (2004-2022). Our EDA is organized into five sections, each designed to build understanding of the target variable of vote share, traditional and advanced metric relationships, and temporal patterns that will inform our regression modeling.
#
# We first explore MVP vote share and the statistical profile of MVP winners by examining the distribution of vote share across all vote-getters, winners, and runners-up in histograms. We then compare the statistical profiles of MVP winners across the pre-analytics and modern eras. This establishes a baseline understanding of what the MVP award looks like numerically and how the typical MVP winner has changed over time.
#
# We then explore the shifting determinants of MVP voting behavior by using stratified scatter plots of key traditional and advanced metrics against vote share and further split them by pre-2004 and post-2004 eras. By comparing simple linear regression slopes across eras, this section directly investigates whether the relationship between specific statistics and MVP voting outcomes has strengthened or weakened since the analytics movement began.
#
# Next, we look at the evolution of traditional and advanced metrics of MVP vote getters through time series plots by tracking the median values of traditional and advanced metrics across all 26 seasons, with IQR shading to show variation. The 2003-04/2004-05 boundary is marked to visually identify our focal turning point around which we are looking how MVP candidates' statistical profiles changed over time.
#
# Our next section examines pairplots and a correlation heatmap across traditional and advanced metrics to identify features that share significant redundant information. The findings directly inform which features to include or exclude in the regression models to avoid multicollinearity.
#
# Finally, we extended this investigation by applying PCA separately to raw metrics, derivative advanced metrics, and a combined feature set stratified by era for MVP vote-getters only. This quantified the redundancy in the feature space and provided visual evidence of whether the primary dimension of MVP-relevant statistical variation has shifted from traditional toward advanced metrics post-2004. However, we did not continue with PCA into the final analyses. To see the code responsible for PCA see `02-EDACheckpoint.ipynb`.
#
# To see the code responsible for EDA figures see `02-EDACheckpoint.ipynb`. We will load saved figures from here.

# %% [markdown]
# #### Section 1 of EDA: MVP Vote Share Histograms and Statistical Profile of MVP Winners
#
# To understand the target variable before modeling, we first examine how MVP vote share is distributed among all vote-getters across the 26 seasons. Because the voting structure allows multiple candidates to receive points, the distribution is expected to be heavily right-skewed — most players who receive any votes at all collect only a small fraction of the total. We then isolate only the actual MVP winners (the top vote-getter each season) and compare their key statistical profiles across the pre-analytics (1996–2004) and modern (2004–2022) eras using boxplots. This gives us a concrete picture of how the "MVP profile" has shifted alongside the broader analytics movement, complementing the time series trends shown in Section 3.

# %% [markdown]
# __Figure 1__
#
# We start by creating histograms of the vote shares of all MVP vote getters, the MVP winners, and the MVP runner ups for the entire period from the 1996-1997 NBA season to the 2021-2022 NBA season.

# %%
import matplotlib.image as mpimg

img = mpimg.imread('results/vote_share_distribution.png')
plt.figure(figsize=(16, 6), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The vote share histograms confirm that MVP voting is heavily concentrated among very few players each season. Among all vote-getters, the distribution is strongly right-skewed with a median share well below 0.10, meaning most players who appear on any ballot collect only a small fraction of the vote. The winners-only histogram reinforces this — actual MVPs consistently command between 0.80 and 1.00 vote share with a median vote share of 0.927. Furthermore, the runners-up histogram shows that second-place finishers rarely exceed 0.80, but still have a respectable median vote share of 0.711. The three histograms together show that MVP races are often a competition between only one or two dominant players per season.

# %% [markdown]
# __Figure 2__
#
# Next, we will show advanced metrics and scoring output of MVP winners grouped by the Pre-Analytics (1996-2004) and Modern (2004-2022) era through a series of box plots.

# %%
img = mpimg.imread('results/statistical_profile_mvp_winners.png')
plt.figure(figsize=(16, 8), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The era comparison boxplots reveal meaningful shifts in the statistical profile of MVP winners post-2004. Points per game remains relatively stable across both eras, consistent with Section 1's finding that raw scoring stayed relevant but became insufficient on its own. The clearest changes appear in the efficiency and impact metrics: True Shooting %, BPM, and WS/48 all show higher median values in the modern era, reflecting that modern MVP winners increasingly fit the mold of players who combined scoring output with broader contributions to winning. PER also rises notably, consistent with the modern MVP being a more complete two-way or playmaking contributor rather than a pure scorer. Taken together, these distributions support the hypothesis that the modern MVP profile has shifted toward advanced efficiency metrics alongside — not instead of — traditional production.

# %% [markdown]
# #### Section 2 of EDA: The Shifting Determinants of MVP Voting Behavior
#
# This section of our exploratory data analysis examines how the relationship between player performance metrics and NBA MVP vote share has evolved before and after the 2004 pivot point commonly associated with the rise of analytics-driven basketball evaluation. By comparing side-by-side scatter plots across the Pre-Analytics Era (1996–2004) and the Modern Era (2004–2022), this section investigates whether traditional statistics such as points per game became less predictive of MVP voting outcomes, while efficiency-oriented metrics such as effective field goal percentage (eFG%) and Win Shares Per 48 (WS/48) became more strongly associated with voter recognition.

# %% [markdown]
# __Figure 1__
#
# We start by looking at a side-by-side scatterplot of the traditional box score metric of points per game by MVP vote getters grouped by era.

# %%
img = mpimg.imread('results/raw_scoring_shift.png')
plt.figure(figsize=(16, 6), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The side-by-side scatter plots reveal a surprising finding that challenges our initial hypothesis. Points per game demonstrated a nearly identical correlation with MVP vote share in both the Pre-Analytics Era (r = 0.406) and the Modern Era (r = 0.404), suggesting that raw scoring output has remained a consistently stable predictor of MVP voting behavior across both periods.
#
# However, the plots are still distinct as the Modern Era plot displays a noticeably wider dispersion of data points around the regression line, particularly among high-scoring players. This increased scatter suggests that while scoring remains equally correlated with vote share on average, it has become a less sufficient condition for MVP contention in the modern era with high scoring output alone no longer guaranteeing media recognition the way it once did.

# %% [markdown]
# __Figure 2__
#
# We then examine a side-by-side scatterplot of the efficiency metric of effective field goal percentage by MVP vote getters grouped by era.

# %%
img = mpimg.imread('results/effective_field_goal_shift.png')
plt.figure(figsize=(16, 6), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The side-by-side scatter plots suggest a notable shift in the relationship between effective field goal percentage (eFG%) and MVP vote share when the data is stratified around the 2004 pivot point. In the Pre-Analytics Era (1996–2004), the relationship between shooting efficiency and MVP vote share appears relatively weak (r = 0.140), as indicated by the slight upward slope of the regression line. While some highly efficient scorers received substantial MVP support, efficient shooting alone does not appear to have been a major distinguishing characteristic of MVP voting outcomes during this period.
#
# In contrast, the Modern Era (2004–2022) demonstrates a substantially stronger positive relationship between eFG% and MVP vote share. The steeper regression slope, larger correlation coefficient of 0.309, and higher concentration of top vote shares among players with elevated efficiency metrics suggest that shooting efficiency became more closely associated with MVP recognition in the post-2004 era. This visible strengthening of the relationship between efficiency and MVP vote share may reflect the growing influence of advanced metrics in MVP voting.

# %% [markdown]
# __Figure 3__
#
# Finally, we will look at a side-by-side scatterplot of the advanced metric of win shares per 48 by MVP vote getters grouped by era.

# %%
img = mpimg.imread('results/win_shares_shift.png')
plt.figure(figsize=(16, 6), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The side-by-side scatter plots suggest a strengthening relationship between Win Shares Per 48 minutes (WS/48) and MVP vote share when the data is stratified around the 2004 pivot point. In the Pre-Analytics Era (1996–2004), the relationship between WS/48 and MVP vote share appears positive, although the dispersion of points indicates that the metric was not consistently aligned with MVP voting outcomes. While players with higher WS/48 values often received greater MVP support, the relationship is more moderate during this period with a correlation coefficient of 0.526.
#
# In contrast, the Modern Era (2004–2022) demonstrates a noticeably steeper positive relationship, a correlation coefficient of 0.614, between WS/48 and MVP vote share. Players with higher efficiency and overall impact metrics appear more consistently associated with stronger MVP vote shares in the post-2004 period. This strengthened relationship may reflect the increasing influence of advanced analytics and efficiency-based evaluation metrics in modern MVP voting patterns.

# %% [markdown]
# #### Section 3 of EDA: Time series plots of traditional/advanced metrics across the 26 seasons
#
# We plotted the median value of each traditional and advanced metric per season among only players who received at least
# one MVP vote (share > 0). The shaded band shows the interquartile range (25th to 75th percentile), to show how much variation exists among candidates in a given season. The red dashed line marks the 2003-04 / 2004-05 boundary that we have in our hypothesis.

# %% [markdown]
# __Figure 1__
#
# We start with the time series plots of traditional metrics.

# %%
img = mpimg.imread('results/traditional_metrics_time_series.png')
plt.figure(figsize=(16, 10), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# We can see a steady rise after 2004 in Points Per Game, Assists Per Game, and Effective Field Goal %. Unlike what we predicted, we can see that voters didnt abandon traditional metric altogether. However, other metrics like Steals Per Game has a downward trend, showing that MVP candidates are no longer chosen based on stealing the ball post 2004. Same thing for Blocks Per Game. As for Turnovers Per Game and Rebounds Per Game, we can see some noise that doesnt indicate a steady upward or downward trend.

# %% [markdown]
# __Figure 2__
#
# We then create the time series plots of advanced metrics.

# %%
img = mpimg.imread('results/advanced_metrics_time_series.png')
plt.figure(figsize=(16, 10), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# We can see a consistent rising trend in True Shooting %, reflecting a league wide shift toward overall scoring efficiency.
# Box Plus/Minus and Player Efficiency Rating shows an upward trend post 2004, showing that MVP candidates are now distinguished by their overall productivity and impact on the performance (not only with counting stats that measures on the individual scope). VORP, net rating, and Win Shares per 48 min don't't show a consistent trend, as they are very voltaile. Usage Rate shows little movement post 2004 with a wide IQR, suggesting high variability and showing that the importance of the degree of ball possession didn't change over time.
#
#
# Taken together with the traditional metric time series plots, the trends suggest that the modern MVP metrics is not a replacement of traditional stats with advanced ones, but rather a combination of both (candidates who score more, assist more, and do so with greater efficiency than their pre-2004 counterparts).

# %% [markdown]
# #### Section 4 of EDA: Finding MultiCollinearities Among Player Statistics and Advanced Metrics
#
# In this section, we examine the relationships between numerous pairs of player stats, efficiency metrics, and advanced metrics in order to determine if we have any multicollinearities to watch out for before conducting our multiple regression model. We start by looking at paired scatterplots for metrics and advanced metrics are focused on the same element of a basketball player's performance, such as total rebounds (reb) with offensive rebound percent (oreb_pct) and defensive rebound percent (dreb_pct). Then, we look at a correlation heatmap with both player statistics and advanced metrics in order to look for multicolinearities due to the fact that some advanced metrics are calculated based on other advanced metrics or player statistics, such as VORP being a rough calculation of a player's BPM times their minutes played.

# %% [markdown]
# __Figure 1__
#
# We will first create a pair plot looking at the three metrics/statistics in our dataset that relate to a player's rebounding: total rebounds, offensive rebound percentage, and defensive percentage.

# %%
img = mpimg.imread('results/pairplot_rebound.png')
plt.figure(figsize=(10, 6), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The pairplot for these rebounding statistics and metrics show that the distribution of each of these features is slightly right skewed. Furthermore, each paired scatterplot of the metrics show relatively weak to moderate positive correlation between the 3 pairings of these rebounding metrics. The strongest positive correlation appears to be the relationship between the total rebounds and defensive rebound percentage features. However, this relationship does not immediately appear strong enough to indicate strong multicollinearity between these rebounding metrics.
#
# Additionally, the weaker relationships involving offensive rebound percentage suggest that offensive rebounding may capture a different aspect of player performance compared to total rebounding and defensive rebounding percentage. This distinction may provide additional explanatory value in later regression modeling. Because of this, we will not drop any of these rebounding metrics from the potential feature set of a multi regression model.

# %% [markdown]
# __Figure 2__
#
# Next, we will create a scatter plot looking at the two metrics/statistics in our dataset that relate to a player's scoring efficiency: true shooting percentage and effective field goal percentage.

# %%
img = mpimg.imread('results/scatterplot_efficiency.png')
plt.figure(figsize=(6, 4), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The scatterplot for the two scoring efficiency metrics of effective field goal percentage (eFG%) and true shooting percentage (ts_pct) shows that these metrics are very strongly positively correlated (r = 0.938). This makes sense because both of these scoring efficiency metrics are derived from a player's field goal and their three point shooting performance. In addition to these field goal and 3 point shooting performances, true shooting percentage also takes into account a player's free throw attempts which makes it a more complex metric.
#
# Due to the extremely strong positive correlation observed between effective field goal percentage and true shooting percentage, these variables may introduce severe multicollinearity if included simultaneously in a multiple regression model. To reduce multicollinearity in our model, only one of these scoring efficiency metrics will be retained in the final regression model. We will retain effective field goal percentage because it captures overall shooting efficiency while avoiding additional overlap with free throw rate (FTr).

# %% [markdown]
# __Figure 3__
#
# Next, we will create a pair plot looking at the four metrics/statistics in our dataset that relate to a player's playmaking: assists, turnovers, turnover percentage, and usage percentage.

# %%
img = mpimg.imread('results/pairplot_playmaking.png')
plt.figure(figsize=(16, 10), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The pairplot for these playmaking and offensive involvement metrics shows that the distribution of assists (ast), turnovers (TOV), and turnover percentage (TOV%) are moderately right skewed, while usage percentage (usg_pct) appears to be an approximately normal distribution. Furthermore, several paired scatterplots show moderately positive correlations between the different playmaking metrics.
#
# The strongest positive correlations appear between assists and turnovers, as well as between turnovers and usage percentage. These relationships are expected because players with greater offensive loads and ball-handling responsibilities typically generate more assists while also committing more turnovers. Additionally, players with higher usage percentages generally have possession of the ball more frequently, leading to an increase in both playmaking and turnover opportunities.
#
# Turnover percentage shows a weaker and slightly negative relationship with usage percentage. This suggests that while high-usage players may commit more total turnovers, they are not necessarily less efficient at protecting the ball. Similarly, the weaker relationship between assists and turnover percentage indicates that strong playmakers do not always exhibit disproportionately high turnover rates.
#
# These playmaking metrics appear to contain overlapping but non-identical information regarding offensive creation and ball dominance. While some moderate multicollinearity may exist between assists, turnovers, and usage percentage, these relationships do not immediately appear strong enough to indicate severe multicollinearity concerns for later regression modeling. As a result, we will retain all of these features.

# %% [markdown]
# __Figure 4__
#
# Finally, we examine a broader collection of traditional player statistics and advanced metrics simultaneously through a correlation heatmap in order to identify potential multicollinearity relationships across different categories of player performance. Unlike the previous pairplots, which focused on metrics measuring similar basketball skills, this visualization allows us to concisely investigate whether certain advanced metrics may contain overlapping information with traditional statistics or with one another due to their underlying calculations. We are particularly interested in identifying strong correlations involving composite advanced metrics such as BPM, VORP, PER, and WS/48.

# %%
img = mpimg.imread('results/heatmap_player_stats.png')
plt.figure(figsize=(10, 6), dpi=150)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The correlation heatmap for these traditional player statistics and advanced metrics shows a mixture of weak, moderate, and extremely strong positive correlations between several variables. Many of the offensive production and advanced impact metrics display noticeable positive linear relationships, while defensive counting statistics such as steals (STL) and blocks (BLK) generally exhibit weaker correlations with the remaining features.
#
# The strongest positive relationships appear between the advanced metrics: box plus minus (BPM), value over replacement player (VORP), win shares per 48 (WS/48), and player efficiency rating (PER). These strong correlations are expected because each of these metrics attempts to summarize a player's overall impact and efficiency using overlapping box score statistics and efficiency measures. The two variables VORP and BPM appear to have the strongest positive linear correlation (0.87), which is due to the fact that VORP is directly calculated from BPM and a player's minutes played. This suggests that one of these two metrics must be dropped before continuing with the creation of a multiple regression model.
#
# Across the entire heatmap, PER seems to have the most strongly positive correlations with other features, with the most notable ones being points (0.76), VORP (0.78), BPM (0.86), and WS/48 (0.83). Due to PER being a composite metric of all of a player's positive and negative contributions on the court, it is expected to be largely correlated with many features. This indicates that PER should be removed from the feature list due to the large number of multicollinearities it can introduce.
#
# Advanced metrics that show much weaker correlations with the other traditional and advanced metrics are free throw rate (FTr) and net rating (net_rating). This suggests that both free throw rate and net rating may capture a unique aspect of a player's game that the other metrics do not.
#
# Due to the strong positive relationships shown by the advanced metrics BPM, VORP, WS/48, and PER in this heatmap, it becomes clear that including all of these advanced metrics in the multiple regression model would create severe multicollinearities. The likely metrics to drop are VORP and PER due to their composition of many other advanced metrics or traditional statistics that are already present in the dataset.

# %% [markdown]
# ### Analysis 1: Multiple Linear Regression on Full Time Period (1996-2022)
#
# To investigate which statistical factors most strongly predict NBA MVP vote share, we fit a Multiple Linear Regression model on all player-seasons that received at least one MVP vote between 1996 and 2022. We created this subset to prevent the zero-inflated mvp vote share that Multiple Linear Regression does not handle well. The model regresses vote share against eleven predictors spanning both traditional box score metrics (points, assists, rebounds, steals, blocks, and turnovers) and advanced efficiency metrics (effective field goal percentage, usage rate, net rating, win shares per 48 minutes, and box plus-minus). All predictors are standardized prior to fitting so that the resulting coefficients are directly comparable. A larger absolute coefficient indicates a stronger influence on vote share regardless of the original unit of measurement. By examining the direction and magnitude of each standardized coefficient, this analysis allows us to quantify the relative importance of traditional versus advanced metrics in explaining MVP voting behavior across the full sample period.
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %%
# This cell sets up and carries out the Multiple Linear Regression on players with non-zero MVP vote share across the entire period from (1996-2022)
# import OLS regression dependencies
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf

traditional_vars = ['pts', 'ast', 'reb', 'STL', 'BLK', 'TOV']
advanced_vars = ['eFG%', 'usg_pct', 'net_rating', 'WS/48', 'BPM', 'TOV%']
all_predictors = traditional_vars + advanced_vars
target = 'share'

# subset to vote-getters only
df_mvp = df_merged[df_merged['share'] > 0].copy()

# standardize predictors so coefficients are directly comparable
scaler = StandardScaler()
df_mvp[all_predictors] = scaler.fit_transform(df_mvp[all_predictors])

# build formula string e.g. 'share ~ pts + ast + reb + ...'
# rename columns with '/' or '%' to make a clean formula
df_mvp = df_mvp.rename(columns={
    'WS/48': 'WS_per_48',
    'eFG%':  'eFG_pct',
    'TOV%':  'TOV_pct'
})
all_predictors_clean = ['pts', 'ast', 'reb', 'STL', 'BLK', 'TOV',
                        'eFG_pct', 'usg_pct', 'net_rating', 'WS_per_48', 'BPM', 'TOV_pct']

formula = 'share ~ ' + ' + '.join(all_predictors_clean)
print("Using the Formula:", formula)

# fit model
print("\n========== FULL-PERIOD MLR MODEL (1996–2022) ==========")
model_full = smf.ols(formula, data=df_mvp).fit()
print(model_full.summary())

# plot coefficients
coef_df = pd.DataFrame({
    'variable': all_predictors_clean,
    'coef':     [model_full.params[v] for v in all_predictors_clean],
    'ci_low':   [model_full.conf_int().loc[v, 0] for v in all_predictors_clean],
    'ci_high':  [model_full.conf_int().loc[v, 1] for v in all_predictors_clean],
    'pval':     [model_full.pvalues[v] for v in all_predictors_clean]
}).sort_values('coef', ascending=True)

fig, ax = plt.subplots(figsize=(9, 7))
colors = ['#2196F3' if c > 0 else '#FF5722' for c in coef_df['coef']]
ax.barh(coef_df['variable'], coef_df['coef'], color=colors, alpha=0.85, edgecolor='white')
ax.axvline(0, color='black', linewidth=0.8, linestyle='--')
ax.set_xlabel('Standardized Coefficient (β)', fontsize=11)
ax.set_ylabel('Feature', fontsize=11)
ax.set_title('Full-Period MLR: Standardized Coefficients (1996–2022)', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
# Out:
# Using the Formula: share ~ pts + ast + reb + STL + BLK + TOV + eFG_pct + usg_pct + net_rating + WS_per_48 + BPM + TOV_pct
#
# ========== FULL-PERIOD MLR MODEL (1996–2022) ==========
#                             OLS Regression Results
# ...
# Dep. Variable:                  share   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     27.58
# Date:                Sun, 07 Jun 2026   Prob (F-statistic):           1.74e-44
# Time:                        23:01:01   Log-Likelihood:                 70.494
# No. Observations:                 386   AIC:                            -115.0
# Df Residuals:                     373   BIC:                            -63.56
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# The full-period OLS regression model explains approximately 47% of the variance in MVP vote share (R² = 0.470, Adjusted R² = 0.453), suggesting that player statistics capture a meaningful but incomplete picture of MVP voting behavior. Among individual predictors, net rating (β = 0.046, p = 0.002) and WS/48 (β = 0.105, p < 0.001) emerged as the only statistically significant positive predictors, suggesting that overall team impact and efficiency are the strongest measurable drivers of MVP recognition. Another notable outcome is that traditional box score statistics including points, assists, rebounds, steals, and blocks all had relatively low coefficient absolute values and a higher p-value (p > 0.05). Effective field goal percentage was the only significant negative predictor (β = -0.040, p = 0.019), which seems counterintuitive, but may be a result of MVP vote share being more guard dominated during this time period as centers generally have higher eFG%. Several important limitations apply to these results. The non-normal residuals confirmed by the Omnibus test (p = 0.000) and Jarque-Bera test (p = 4.08e-11) mean that reported p-values and confidence intervals are approximations. Additionally, by restricting the sample to players who already received MVP votes, the model captures what differentiates MVP candidates from each other but cannot be generalized to explain what determines MVP candidacy in the first place. These limitations collectively motivate the Random Forest analysis that follows, which makes no distributional assumptions and handles correlated predictors more robustly through its ensemble structure.

# %% [markdown]
# ### Analysis 2: Multiple Linear Regression Stratified by Era
#
# To investigate whether the statistical predictors of NBA MVP vote share shifted across eras, we stratify the same vote-getter subset into two periods defined by the 2004 publication of Dean Oliver's Basketball on Paper: the Pre-Analytics Era (1996–2004) and the Modern Era (2004–2022). A separate Multiple Linear Regression model is fit on each era using the same eleven predictors as the full-period model, with predictors re-standardized within each era so that coefficients reflect the relative importance of each stat in that specific period rather than across the full sample. By comparing the standardized coefficients side by side, this analysis allows us to directly test our hypothesis of advanced efficiency metrics gaining predictive power over traditional box score statistics in the modern era as media voters became more exposed to analytics-based evaluation.

# %%
# This cell sets up and carries out the Multiple Linear Regression on players with non-zero MVP vote share stratified by
# the pre-analytics (1996-1997 to 2003-2004) and the modern eras (2004-2005 to 2021-2022)

# add era column to df_mvp
df_mvp['start_year'] = df_mvp['season'].str[:4].astype(int)
df_mvp['era'] = df_mvp['start_year'].apply(
    lambda s: 'pre_analytics' if s < 2004 else 'modern'
)

era_models = {}

# fit model for each era
for era_name, label in [('pre_analytics', 'Pre-Analytics Era (1996–2004)'),
                         ('modern', 'Modern Era (2004–2022)')]:
    df_era = df_mvp[df_mvp['era'] == era_name].copy()

    # re-standardize within era
    scaler = StandardScaler()
    df_era[all_predictors_clean] = scaler.fit_transform(df_era[all_predictors_clean])

    model_era = smf.ols(formula, data=df_era).fit()
    era_models[era_name] = model_era

    print(f"\n========== {label} ==========")
    print(model_era.summary())

# plot coefficients for each era in a side by side bar graph
coef_rows = []
for era_name, label in [('pre_analytics', 'Pre-Analytics (1996-2004)'),
                         ('modern', 'Modern (2004-2022)')]:
    m = era_models[era_name]
    for var in all_predictors_clean:
        coef_rows.append({
            'era': label,
            'variable': var,
            'coef': m.params[var]
        })

coef_df_era = pd.DataFrame(coef_rows)

fig, ax = plt.subplots(figsize=(11, 7))
y_pos = np.arange(len(all_predictors_clean))
width = 0.35

for i, (era, color) in enumerate([('Modern (2004-2022)', '#FF5722'),
                                   ('Pre-Analytics (1996-2004)', '#2196F3')]):
    group  = coef_df_era[coef_df_era['era'] == era]
    offset = (i - 0.5) * width
    ax.barh(y_pos + offset, group['coef'], width,
            label=era, color=color, alpha=0.85, edgecolor='white')

ax.axvline(0, color='black', linewidth=0.8, linestyle='--')
ax.set_yticks(y_pos)
ax.set_yticklabels(all_predictors_clean, fontsize=10)
ax.set_xlabel('Standardized Coefficient (β)', fontsize=11)
ax.set_ylabel('Feature', fontsize=11)
ax.set_title('Era Comparison: Standardized Regression Coefficients\n'
             'Pre-Analytics (1996-2004) vs. Modern (2004-2022)', fontsize=12)
ax.legend([plt.Rectangle((0,0),1,1, color='#2196F3', alpha=0.85),
           plt.Rectangle((0,0),1,1, color='#FF5722', alpha=0.85)],
          ['Pre-Analytics (1996-2004)', 'Modern (2004-2022)'],
          fontsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
# Out:
# ========== Pre-Analytics Era (1996–2004) ==========
#                             OLS Regression Results
# ...
# Dep. Variable:                  share   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     9.787
# Date:                Sun, 07 Jun 2026   Prob (F-statistic):           2.65e-13
# Time:                        23:01:01   Log-Likelihood:                 38.647
# No. Observations:                 140   AIC:                            -51.29
# Df Residuals:                     127   BIC:                            -13.05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1486      0.016      9.121      0.000       0.116       0.181
# ...

# %% [markdown]
# The era-stratified models reveal meaningful shifts in how statistical factors predicted MVP vote share across the two periods. In the Pre-Analytics Era (1996–2004), the model explains 48% of the variance (R² = 0.480, Adjusted R² = 0.431) with points per game emerging as strongest positive predictor (β = 0.178, p = 0.025), consistent with the expectation that traditional scoring output was the dominant driver of MVP recognition during this period. Effective field goal percentage was the strongest  negative predictor (β = -0.079, p = 0.007), echoing the full-period finding. In the Modern Era (2004–2022), the model explains a slightly higher 51% of variance (R² = 0.511, Adjusted R² = 0.486). The predictor landscape shifts notably as points per game shows negligible predictive power (β = -0.001, p = 0.982), while WS/48 emerges as the strongest positive predictor (β = 0.129, p < 0.001) and BPM shifts from a negative predictor to a positive predictor (β = -0.010 to β = 0.057). This shift from points to win shares as the dominant predictor across eras provides direct support for our hypothesis that advanced efficiency metrics gained predictive power in the modern era as media voters increasingly incorporated analytics-based evaluation into their decision making. However, both models share the same limitations as the full-period model with non-normal residuals and a restricted sample of only MVP vote-getters.

# %% [markdown]
# ### Analysis 3: Ridge Regression Stratified by Era (Pre- vs Post-2004)
#
# Analysis 1 fit a single model across the full period. To test that the predictive importance of advanced metrics shifted after the 2003-04 rule, we use **Ridge regression** rather than ordinary least squares because our predictors are highly collinear (see the correlation heatmap above): metrics such as PER, BPM, WS/48, and net rating have overlapping information, making plain OLS coefficients unstable and difficult to interpret. Ridge adds an L2 penalty that shrinks coefficients toward zero, which stabilizes them in the presence of collinearity so that we reduce the noise and the comparison shows real signals.

# %%
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler

traditional_vars = ['pts', 'ast', 'reb', 'STL', 'BLK', 'TOV']
advanced_vars    = ['eFG%', 'usg_pct', 'net_rating', 'WS/48', 'BPM', 'TOV%']
all_predictors   = traditional_vars + advanced_vars
target           = 'share'

# Vote-getters only 
df_era = df_merged[df_merged['share'] > 0].copy()

df_era['start_year'] = df_era['season'].str[:4].astype(int)
df_era['era'] = np.where(df_era['start_year'] >= 2004, 'Modern (2004-2022)', 'Pre-Analytics (1996-2004)')

# Helper function: fit a RidgeCV model on one era's data. Reusable for all eras
def fit_ridge_for_era(era_df, predictors, target):
    scaler = StandardScaler()
    X = scaler.fit_transform(era_df[predictors])
    y = era_df[target].values

    # RidgeCV tries several penalty strengths and picks the best one through cross-validation
    alphas = np.logspace(-3, 3, 50)        # 50 candidates for penalty strengths
    model = RidgeCV(alphas=alphas).fit(X, y) # Tries all 50 candidates and fit the best one

    coefs = pd.Series(model.coef_, index=predictors)
    r2 = model.score(X, y)              
    return model, coefs, r2, model.alpha_

# Fit one model per era
results = {}
for era_name, era_df in df_era.groupby('era'):
    model, coefs, r2, alpha = fit_ridge_for_era(era_df, all_predictors, target)
    results[era_name] = {'coefs': coefs, 'r2': r2, 'alpha': alpha, 'n': len(era_df)}
    print(f"{era_name}: n={len(era_df)}, R^2={r2:.3f}, chosen alpha={alpha:.3g}")

# coefficient table (pre vs post)
pre_name  = 'Pre-Analytics (1996-2004)'
post_name = 'Modern (2004-2022)'
coef_compare = pd.DataFrame({
    'Pre-2004':  results[pre_name]['coefs'],
    'Post-2004': results[post_name]['coefs'],
})

coef_compare['change'] = coef_compare['Post-2004'] - coef_compare['Pre-2004']
coef_compare['type'] = ['Traditional' if v in traditional_vars else 'Advanced' for v in coef_compare.index]

print("\nStandardized Ridge coefficients by era:")
print(coef_compare.round(4))

order = coef_compare.sort_values('Post-2004').index
y_pos = np.arange(len(order))
bar_h = 0.4

fig, ax = plt.subplots(figsize=(9, 8))
ax.barh(y_pos + bar_h/2, coef_compare.loc[order, 'Pre-2004'],
        height=bar_h, label='Pre-2004', color='#5B9BD5', alpha=0.9, edgecolor='white')
ax.barh(y_pos - bar_h/2, coef_compare.loc[order, 'Post-2004'],
        height=bar_h, label='Post-2004', color='#ED7D31', alpha=0.9, edgecolor='white')
ax.axvline(0, color='black', linewidth=0.8, linestyle='--')
ax.set_yticks(y_pos)
ax.set_yticklabels(order)
ax.set_xlabel('Standardized Ridge Coefficient (β)', fontsize=11)
ax.set_ylabel('Feature', fontsize=11)
ax.set_title('Ridge Regression by Era: Standardized Coefficients (Pre vs Post 2004)', fontsize=12)
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
# Out:
# Modern (2004-2022): n=246, R^2=0.506, chosen alpha=25.6
# Pre-Analytics (1996-2004): n=140, R^2=0.460, chosen alpha=25.6
#
# Standardized Ridge coefficients by era:
#             Pre-2004  Post-2004  change         type
# pts           0.0451     0.0165 -0.0286  Traditional
# ast           0.0206    -0.0015 -0.0221  Traditional
# reb           0.0444     0.0196 -0.0248  Traditional
# STL          -0.0078    -0.0195 -0.0118  Traditional
# BLK           0.0106    -0.0231 -0.0337  Traditional
# TOV           0.0086     0.0332  0.0246  Traditional
# eFG%         -0.0318    -0.0034  0.0283     Advanced
# usg_pct       0.0226     0.0350  0.0124     Advanced
# net_rating    0.0482     0.0341 -0.0141     Advanced
# WS/48         0.0505     0.0973  0.0468     Advanced
# BPM           0.0354     0.0586  0.0232     Advanced
# TOV%         -0.0105     0.0273  0.0378     Advanced

# %% [markdown]
# - The era stratified Ridge models support our hypothesis. Advanced metrics gained predictive weight in the Modern era as can be seen:
# 1- WS/48 nearly doubled (β = 0.051 --> 0.097). This is the strongest predictor in either era
# 2- BPM (0.035 --> 0.059)
#
# - On the other hand, traditional box-score metrics declined (points 0.045 --> 0.017, rebounds 0.044 --> 0.020, assists 0.021 --> −0.002).
#
# - net_rating is the one advanced metric that did not rise post 2004.
# - Moreover, we can see a drop in the points coefficient post 2004 but that does not mean scoring stopped mattering as our EDA showed that points correlates with vote share around 0.40 in both eras. This decline in the coefficient is mainly because WS/48 and BPM. They contain scoring information as well as other information that carries more weight in the model, such that it absorbs most of the signal before the raw points variable (hence why it has a less weight in this model).
#
#
#
# This Ridge model addresses the unstability in the model above, which is caused by the collinearity in our features. For example, eFG% pre-2004 looks like a negative predictor (in analysis 2, β = −0.079, p = 0.007, compared to analysis 3 in which β = -0.031) and BPM flipped signs between the two eras (analysis 3 shows that they stayed positive in both eras). However, Ridge model has a constraint because it gives no p-values, so it doesnt show statistical significance.

# %% [markdown]
# ### Analysis 4: Random Forest Regression on Full Time Period (1996-2022)
#
# To complement and extend the findings of the MLR and Ridge Regression analyses, we fit a Random Forest Regressor on the full dataset of all player-seasons between 1996 and 2022, including players with zero MVP vote share. Unlike the linear models, Random Forest requires no assumptions about the distribution of the target variable, allowing us to use the complete dataset without subsetting to vote-getters or removing correlated predictors. This enables the inclusion of a broader feature set of seventeen predictors spanning traditional box score metrics and advanced efficiency metrics including VORP and PER, which were excluded from the linear models due to severe multicollinearity concerns. Rather than producing interpretable coefficients, the Random Forest measures feature importance through permutation importance which is a process of randomly shuffling each feature and measuring how much the model's predictive performance drops as a result. A larger drop indicates a more important feature. Model performance is evaluated using 5-fold cross-validated R² to provide a more reliable estimate of predictive accuracy on unseen data. By comparing these permutation importance rankings to the coefficients from the linear models, we can assess whether both fundamentally different methods agree on which statistical factors drive MVP voting behavior.
#
# The code for this step is quite lengthy and takes more than a minute to run. To see the code responsible for analyses see `models/RandomForestRegression.ipynb`.

# %%
# this cell loads the results of the random forest regression model and permutation importance carried out on the full dataset of player seasons 
# spanning the entire time period

# load random forest regression performance metrics
metrics = pd.read_csv('results/rf_full_metrics.csv', index_col=0, header=None).squeeze()
print(f"5-Fold CV R²:   {metrics['cv_r2_mean']:.4f} ± {metrics['cv_r2_std']:.4f}")
print(f"5-Fold CV RMSE: {metrics['cv_rmse_mean']:.4f} ± {metrics['cv_rmse_std']:.4f}")

# load and print era permutation feature importances
perm_full_df = pd.read_csv('results/rf_full_permutation_importance.csv')
print("Full-Period Permutation Importance:")
print(perm_full_df.to_string(index=False))

# load and display permutation feature importance plot
img = mpimg.imread('results/rf_permutation_importance_full.png')
fig, ax = plt.subplots(figsize=(11, 5), dpi=150)
ax.imshow(img)
ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 5-Fold CV R²:   0.6606 ± 0.0837
# 5-Fold CV RMSE: 0.0366 ± 0.0061
# Full-Period Permutation Importance:
#    feature  importance
#       VORP    0.177874
#        PER    0.093718
#        BPM    0.082860
# net_rating    0.070034
#      WS/48    0.066999
#        pts    0.054179
#    usg_pct    0.043063
#        TOV    0.039529
#        ast    0.016171
#        BLK    0.011274
#     ts_pct    0.011160
#        reb    0.010853
#       eFG%    0.009632
#        FTr    0.009031
#   dreb_pct    0.008139
#        STL    0.006370
#   oreb_pct    0.006112

# %% [markdown]
# The full-period Random Forest model achieves a 5-fold cross-validated R² of 0.6606 ± 0.0837, explaining approximately 66% of the variance in MVP vote share across the full dataset of all player-seasons from 1996 to 2022. This shows a meaningful improvement over the full-period MLR model (R² = 0.470), which is expected given that Random Forest makes no distributional assumptions and can capture non-linear relationships between predictors and vote share that OLS cannot.
#
# The permutation importance rankings reveal that advanced metrics dominate the top of the feature importance hierarchy across the full period. VORP emerges as the single most important predictor by a considerable margin (0.178), followed by PER (0.094), BPM (0.083), net rating (0.070), and WS/48 (0.067). This extends the findings of the MLR by also showing that composite impact metrics which capture a player's overall contribution to winning are the strongest drivers of MVP vote share. Another interesting finding is that points per game ranks sixth (0.054) in permutation importance which suggests that scoring output does retain meaningful predictive power in determining MVP candidacy when the dataset is extended to include all player's seasons in our dataset.
#
# Traditional box score statistics including assists, turnovers, blocks, rebounds, and steals all rank in the bottom half of the importance rankings, consistent with the MLR finding that traditional counting stats are weaker predictors of MVP vote share than composite advanced metrics. An important limitation to these results is that the cross-validated R² of 0.6606 leaves approximately 34% of variance unexplained, reinforcing the earlier finding that unquantifiable factors such as team narrative and media perception play a meaningful role in MVP outcomes.

# %% [markdown]
# ### Analysis 5: Random Forest Regression Stratified by Era
#
# To further investigate whether the predictive importance of statistical features shifted across eras, we stratify the full dataset into the same two periods as in Analysis 2. A separate Random Forest Regressor is fit on each era's complete player-season data using the same seventeen predictors as the full-period model, with model performance evaluated using 5-fold cross-validated R² to provide a more reliable estimate of predictive accuracy within each period. Permutation importance is then computed for each era independently, measuring how much each feature's predictive contribution changes when its values are randomly shuffled. By comparing the permutation importance rankings side by side across eras, this analysis directly tests our hypothesis of advanced efficiency metrics such as VORP, BPM, and WS/48 gaining predictive power in the modern era relative to traditional box score statistics.
#
# The code for this step is quite lengthy and takes more than a minute to run. To see the code responsible for analyses see `models/RandomForestRegression.ipynb`.

# %%
# this cell loads the results of the random forest regression model and permutation importance carried out on the full dataset of player seasons 
# stratified by the pre-analytics (1996-1997 to 2003-2004) and the modern eras (2004-2005 to 2021-2022)

# load and print era CV R² and RSME results
era_metrics = pd.read_csv('results/rf_era_metrics.csv', index_col=0)
for era in era_metrics.columns:
    r2_mean   = era_metrics.loc['cv_r2_mean', era]
    r2_std    = era_metrics.loc['cv_r2_std', era]
    rmse_mean = era_metrics.loc['cv_rmse_mean', era]
    rmse_std  = era_metrics.loc['cv_rmse_std', era]
    print(f"{era}:")
    print(f"  5-Fold CV R²:   {r2_mean:.4f} ± {r2_std:.4f}")
    print(f"  5-Fold CV RMSE: {rmse_mean:.4f} ± {rmse_std:.4f}")

# load and print era permutation feature importances
perm_compare = pd.read_csv('results/rf_era_permutation_importance.csv', index_col=0)
print("Era Permutation Importance Rankings:")
print(perm_compare.to_string())

# display era comparison plot
img = mpimg.imread('results/rf_permutation_era_comparison.png')
fig, ax = plt.subplots(figsize=(13, 6), dpi=150)
ax.imshow(img)
ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# pre_analytics:
#   5-Fold CV R²:   0.5343 ± 0.1096
#   5-Fold CV RMSE: 0.0428 ± 0.0022
# modern:
#   5-Fold CV R²:   0.6485 ± 0.1516
#   5-Fold CV RMSE: 0.0366 ± 0.0085
# Era Permutation Importance Rankings:
#             Pre-Analytics (1996-2004)  Modern (2004-2022)
# VORP                         0.076689            0.174827
# PER                          0.137842            0.077756
# BPM                          0.081411            0.075982
# WS/48                        0.055146            0.068486
# net_rating                   0.050925            0.049373
# pts                          0.044056            0.040003
# usg_pct                      0.025234            0.038820
# TOV                          0.017668            0.034110
# ast                          0.017594            0.018407
# reb                          0.019406            0.006860
# ts_pct                       0.008216            0.015150
# BLK                          0.008994            0.006069
# ...

# %% [markdown]
# The era-split Random Forest models show a meaningful improvement in predictive performance in the modern era compared to the pre-analytics era, with 5-fold cross-validated R² increasing from 0.5343 ± 0.1096 in the pre-analytics era to 0.6485 ± 0.1516 in the modern era. This suggests that the statistical predictors in our dataset became more consistently aligned with MVP voting behavior after 2004. However, an important limitation to this result is that the sample size of the modern era is almost triple that of the pre-analytics era, so the modern era had more data to train on to achieve a higher R².
#
# The permutation importance rankings reveal a notable shift in which features drove MVP vote share predictions across the two eras. In the pre-analytics era, PER ranked as the most important predictor (0.138), followed by BPM (0.081), VORP (0.077), WS/48 (0.055), and net rating (0.051). In the modern era, VORP rises from third to first by a considerable margin (0.175), while PER drops from first to third (0.078). This shift is the most direct evidence supporting our hypothesis of advanced metrics being stronger predictors of MVP vote share in the modern era. VORP, a metric that explicitly quantifies a player's marginal value over a replacement-level player, nearly doubled in permutation importance from the pre-analytics era to the modern era while PER, a composite metric of traditional box score statistics, had its permutation importance drop by around 40%.
#
# Another interesting finding is that the permutation importance of points did not change much across eras, but did have the highest permutation importance in both eras among all traditional box score statistics. The other traditional box score statistics including assists, rebounds, steals, and blocks remained consistently low in importance in both eras, suggesting that raw defensive and playmaking counting stats were never primary drivers of MVP recognition across either period. Similar to the full period random forest regression model, these era-specific random forest regression models still leave a consider percentage of variance unexplained which again highlights that factors outside of player statistics, such as team narrative and media perception play a meaningful role in MVP outcomes.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# >  When players sign contracts to play in the NBA, they give their consent for the NBA to publish certain data about them. This data includes the traditional box score statistics and advanced metrics which players know will be used by the media for NBA awards and to be viewed publicly by the fans. The data is originally pulled from the official NBA website, which the NBA players know is fully viewable by fans for interpretation.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# >  We created our time frame to start with the 1996-1997 season because the NBA started tracking detailed play-by-play data during this season. We wanted to limit the human bias (e.g. inflating stats to their favorite team) or error that may come from relying on the mostly human scorekeeper data that exists before the 1996-1997 season.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# >  Our dataset does not include any PII past what is available on the NBA.com player statistics. The existence of the player name in our dataset is needed for attributing player stats and MVP vote share to each individual player. We will remove the player height, player weight, and college columns from the Kaggle dataset to further limit PII exposure.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# >  Our dataset contains the Nationality of each player to allow testing for a bias in voting share against international (non-American) players.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# >  All of the data we are using is retrieved from public datasets that originated from the publicly available NBA player statistics, so there is no sensitive data that requires explicit encryption. The actual data will only be available among the group members of this project and the instruction team of this course.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# >  The data in this project will solely be used for this academic project. The data will be locked in this private GitHub repo once the analysis of the data for this academic project is finished.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# >  We read prior works that reference the narrative surrounding a player's season as a factor to MVP vote share and realize that our model will not consider this. We will adjust our analysis to reflect on our findings in the context for each NBA season or era, if applicable, and highlight this shortcoming of our model in the conclusion.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# >  The player metrics of our dataset favor offensive production and high-usage rate players which disadvantages more defensive-minded players. We used the win shares statistic to better capture how a player contributes to winning.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# >  We will be careful when creating our visualizations, summary statistics, and reports to honestly represent the underlying data. For example, we will take the context of shortened lock out seasons into consideration to scale team wins up to an 82 season.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# >  We have not used any datasets with PII (other than player names), nor have we hypothesized that any PII datapoints would be relevant predictors.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# >  We have been very explicit about the steps of our analyses and carefully explained the rationale of each step to make results easy to reproduce.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# >  The variables in our dataset are collected based on the objective player performance in each game of an NBA season to ensure our model does not rely on discriminatory variables. We will also not use any biometric or PII data when creating our model.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# >  We manually analyzed the results of our model to see if it unfairly favored players on big market teams or even players playing certain positions and extend that to the context of potential voter bias.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# >  We are building a model to decide the strongest predictors of NBA MVP vote share. Because vote share is determined by media voters, optimizing our model will likely capture media voting patterns, which is what we are trying to track.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# >  The models used are regression-based which means that the coefficients can be interpreted as the strength of each variable on MVP vote share. We will also contextualize the model's decisions in the narratives surrounding each era or season to account for the difficult in quantifying such narratives.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# >   We have clearly communicated the fact that our model is reliant on previous media voting which may capture human biases instead of accurately quantifying a player's value.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# >  Due to the NBA MVP being awarded only once a year, we will have the opportunity to compare our model's predictions with the vote share from each subsequent season and address discrepancies on a yearly basis.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# >  We will monitor if narratives based on our model are used to denounce the value of NBA players and will emphasize that our model is based on innately subjective voting data rather than objective player value.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# >  Our model could be used to determine future the vote share in future NBA MVP races when its intended purpose was to analyze the importance of player metrics in prior MVP races. We will clearly specify the scope of our model to be the time frame of 1996 to 2022.

# %% [markdown]
# ## Discusison and Conclusion
#
# This project investigated which statistical factors predict NBA MVP vote share and whether the relative importance of traditional versus advanced metrics shifted following the mainstream adoption of basketball analytics after 2004. Our exploratory data analysis established the foundation for this investigation by confirming the right-skewed distribution of MVP vote share and revealing that advanced efficiency metrics such as WS/48 and eFG% showed stronger correlations with vote share in the modern era compared to the pre-analytics era. The statistical profile of MVP winners also shifted visibly post-2004, with modern winners showing higher median values in BPM, WS/48, and True Shooting Percentage, suggesting that the modern MVP profile increasingly rewarded players who contributed to winning beyond raw counting statistics alone.
#
# The linear models provided more formal evidence of this shift. Across the full-period MLR, WS/48 and net rating emerged as the top 2 positive predictors of MVP vote share each with p-values under 0.05, while traditional counting statistics including points, assists, rebounds, steals, and blocks all had smaller absolute coefficients and p-values of above 0.05. This partially supports our hypothesis as WS/48 emerged as the strongest MVP vote share predictor across the full time period, but points per game did not have much MVP vote share predictive strength. The era-stratified MLR and Ridge Regression revealed that points per game carried the largest positive coefficient in the pre-analytics era but showed a significant drop in the modern era, where WS/48 emerged as the dominant predictor. This shift in coefficient magnitude across eras provides direct support for our hypothesis that advanced efficiency metrics gained predictive power following the analytics movement.
#
# The Random Forest models extended and largely corroborated these findings while adding important nuance. Across the full period, VORP, PER, BPM, net rating, and WS/48 occupied the top five positions in permutation importance. This is consistent with the linear model findings that composite impact metrics are the strongest drivers of MVP recognition through vote share. The most notable era shift was VORP nearly doubling in permutation importance from the pre-analytics to the modern era and rising from third to first in feature importance rankings, providing the strongest evidence that media voters increasingly rewarded players who demonstrated marginal value over replacement level after 2004. Unlike the linear models, however, the Random Forest showed points per game retaining relatively stable permutation importance across both eras, a distinction that reflects the different dataset subsets each method used.
#
# These findings extend the prior work in meaningful ways. Coleman et al. found that points per game was the most significant predictor of MVP ballot appearances in the 1995–2005 period using a Tobit and Probit model, a finding that our era-split MLR and Ridge Regression partially corroborate for the pre-analytics era where points had the largest positive coefficient. However, our modern era models show a significant drop in the points coefficient, suggesting that the dominance of scoring output Coleman et al. identified has eroded in the years since their study. Li and Jia's CatBoost model identified VORP, points, and PER as the top predictors across 1974–2024, which aligns closely with our full-period Random Forest rankings where VORP, PER, and BPM occupied the top three positions. Our work extends theirs by isolating the specific era in which VORP rose to prominence rather than treating the entire historical period as a single sample. Godbole et al. similarly found that advanced metrics grew more influential in their Modern Era (2012–2022), which is consistent with our findings. However, our use of 2004 as the pivot point allows us to identify the shift occurring earlier than their era boundaries suggest.
#
# Bringing the results together, the broader picture that emerges is one of gradual evolution rather than a sudden break. Our EDA showed that the statistical profile of MVP winners shifted toward advanced metrics post-2004, and the era-split models confirmed that the composition of which advanced metrics mattered changed meaningfully, such as VORP gaining prominence as voters became more sophisticated in their evaluation criteria. An important takeaway is that the analytics era did not replace traditional scoring output with advanced metrics, but instead added a new layer of evaluation on top of it.
#
# Our results also contain an important contradiction worth discussing. The Random Forest permutation importance showed points per game retaining relatively stable predictive power across eras, while both the MLR and Ridge Regression showed a significant drop in the points coefficient in the modern era. This discrepancy likely reflects the different datasets each method used. The linear models were restricted to vote-getters only, meaning the points coefficient captures how scoring differentiates MVP candidates from each other, while the Random Forest used all player seasons including zero vote-getters, meaning it captures how scoring distinguishes MVP candidates from the broader player population. This means that scoring remains a strong signal for identifying which players are even in MVP contention, but struggles to separate the top candidates from each other as cleanly as it once did.
#
# Several limitations apply to this work and its interpretability for MVP voting behavior. The restriction of the linear models to vote-getters only, while necessary to avoid zero-inflation, means that those models cannot speak to what gets a player into MVP consideration in the first place. The dataset also lacks team-level variables such as win totals and seeding, which prior research has identified as important contextual factors in MVP voting. This means that a player's team success likely acts as a confounding variable that our models cannot fully account for. Additionally, our model cannot capture the narratives surrounding player's seasons or voter fatigue which leaves additional vote share variance unaccounted for. Finally, our models capture media voting patterns which may reflect human biases such as positional bias and big market favoritism rather than objective player value.
#
# Future work could address these limitations in several ways. Incorporating team wins, net rating, and playoff seeding as additional predictors would allow the models to control for team success and isolate individual statistical contributions more cleanly. Extending the dataset beyond 2022 to include recent seasons would also allow testing of whether the trends identified here have continued or reversed in the post-pandemic era of the NBA. A Tobit regression model could also be applied across both eras to provide a more statistically rigorous treatment of the censored zero vote-share observations than the subsetting approach used here. Finally, natural language processing applied to media coverage and social media data could begin to quantify the narrative factors that our statistical models consistently leave unexplained, potentially closing the gap between the 66% of variance explained by the Random Forest and a more complete model of MVP voting behavior.
